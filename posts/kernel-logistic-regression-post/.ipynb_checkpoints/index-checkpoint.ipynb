# %% [raw]
# ---
# title: Kernel Logistic Regression
# author: Julia Fairbank
# date: '2023-03-13'
# image: "image.jpg"
# description: "Implementing kernel logistic regression, a method for using linear empirical risk minimization to learn nonlinear decision boundaries, CSCI 0451."
# format: html
# ---

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # link to source code
#
# Desktop/juliafairbank7.github.io/posts/kernel-logistic-regression-post/KernelLogisticRegression.py

# %% [markdown]
# # non-linear dataset

# %%
from sklearn.datasets import make_moons, make_circles
from matplotlib import pyplot as plt
import numpy as np
np.seterr(all="ignore")


X, y = make_moons(2, shuffle = True, noise = 0.2)
plt.scatter(X[:,0], X[:,1], c = y)
labels = plt.gca().set(xlabel = "Feature 1", ylabel = "Feature 2")

# %% [markdown]
# # pre-implemented versions of logistic regression & visualization tool

# %%
from sklearn.linear_model import LogisticRegression
from mlxtend.plotting import plot_decision_regions

LR = LogisticRegression()

LR.fit(X, y)

plot_decision_regions(X, y, clf = LR)

title = plt.gca().set(title = f"Accuracy = {(LR.predict(X) == y).mean()}",
                      xlabel = "Feature 1", 
                      ylabel = "Feature 2")

# %% [markdown]
# # kernel logistic regression

# %%
from KernelLogisticRegression import KernelLogisticRegression
from sklearn.metrics.pairwise import rbf_kernel

KLR = KernelLogisticRegression(rbf_kernel, gamma = .1)
KLR.fit(X, y)
plot_decision_regions(X, y, clf = KLR)
title = plt.gca().set(title = f"Accuracy = {(KLR.predict(X) == y).mean()}",
                      xlabel = "Feature 1", 
                      ylabel = "Feature 2")
# Out:
# /Users/juliafairbank/opt/anaconda3/lib/python3.9/site-packages/mlxtend/plotting/decision_regions.py:269: UserWarning: No contour levels were found within the data range.
#   ax.contour(xx, yy, Z, cset.levels, **contour_kwargs)
